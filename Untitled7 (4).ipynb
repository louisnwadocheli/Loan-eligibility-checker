# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import xgboost as xgb
from xgboost import XGBClassifier

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold

from sklearn.ensemble import RandomForestClassifier

from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, make_scorer, roc_curve, auc
from scipy import stats

from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv('dataset_dissertation.csv')

# %%
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')

# %%
df
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
df.isna().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'Secured_by', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'LTV', 'Region', 'Security_Type',
#        'Status', 'dtir1'],
#       dtype='object')

# %%
#df.drop(['ID','year','loan_limit','approv_in_adv','loan_purpose','open_credit','Upfront_charges','Neg_ammortization','Upfront_charges','co-applicant_credit_type','submission_of_application','Security_Type','construction_type'], axis='columns', inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'Secured_by', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'LTV', 'Region', 'Security_Type',
#        'Status', 'dtir1'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
df.rate_of_interest.fillna(df.rate_of_interest.mean(),inplace=True)
df.Interest_rate_spread.fillna(df.Interest_rate_spread.mean(),inplace=True)
df.property_value.fillna(df.property_value.mean(),inplace=True)
df.LTV.fillna(df.LTV.mean(),inplace=True)
df.dtir1.fillna(df.dtir1.mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest                 0
# Interest_rate_spread             0
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value                   0
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
df.dtir1.fillna(df.dtir1.mean(),inplace=True)

# %%
df.term.fillna(df.term.mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest                 0
# Interest_rate_spread             0
# Upfront_charges              39642
# term                             0
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value                   0
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
df
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
df.dropna(subset=['age'], inplace=True)

# %%
df.isna().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3332
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   126
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest                 0
# Interest_rate_spread             0
# Upfront_charges              39595
# term                             0
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value                   0
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        8950
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
plt.figure(figsize=(7,4))
sns.boxplot(x='age', y='income', data=df)
plt.show()

# %%
df.dropna(subset=['income'], inplace=True)

# %%
df
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
#transforming categorical variable to numeric
le = LabelEncoder()
df['Gender']= le.fit_transform(df['Gender'])
#data['Gender'].unique()

# %%
df
# Out:
#             ID  year loan_limit  Gender approv_in_adv loan_type loan_purpose  \
# 0        24890  2019         cf       3         nopre     type1           p1
# 1        24891  2019         cf       2         nopre     type2           p1
# 2        24892  2019         cf       2           pre     type1           p1
# 3        24893  2019         cf       2         nopre     type1           p4
# 4        24894  2019         cf       1           pre     type1           p1
# ...        ...   ...        ...     ...           ...       ...          ...
# 148665  173555  2019         cf       3         nopre     type1           p3
# 148666  173556  2019         cf       2         nopre     type1           p1
# 148667  173557  2019         cf       2         nopre     type1           p4
# 148668  173558  2019         cf       0         nopre     type1           p4
# 148669  173559  2019         cf       0         nopre     type1           p3
#
# ...

# %%
df['loan_type']=le.fit_transform(df['loan_type'])

# %%
df['Credit_Worthiness']=le.fit_transform(df['Credit_Worthiness'])

# %%
df['business_or_commercial']=le.fit_transform(df['business_or_commercial'])

# %%
df['interest_only']=le.fit_transform(df['interest_only'])

# %%
df['lump_sum_payment']=le.fit_transform(df['lump_sum_payment'])

# %%
df
# Out:
#             ID  year loan_limit  Gender approv_in_adv  loan_type loan_purpose  \
# 0        24890  2019         cf       3         nopre          0           p1
# 1        24891  2019         cf       2         nopre          1           p1
# 2        24892  2019         cf       2           pre          0           p1
# 3        24893  2019         cf       2         nopre          0           p4
# 4        24894  2019         cf       1           pre          0           p1
# ...        ...   ...        ...     ...           ...        ...          ...
# 148665  173555  2019         cf       3         nopre          0           p3
# 148666  173556  2019         cf       2         nopre          0           p1
# 148667  173557  2019         cf       2         nopre          0           p4
# 148668  173558  2019         cf       0         nopre          0           p4
# 148669  173559  2019         cf       0         nopre          0           p3
#
# ...

# %%
df['Secured_by']=le.fit_transform(df['Secured_by'])

# %%
df['total_units']=le.fit_transform(df['total_units'])

# %%
df['credit_type']=le.fit_transform(df['credit_type'])

# %%
df['Region']=le.fit_transform(df['Region'])

# %%
df
# Out:
#             ID  year loan_limit  Gender approv_in_adv  loan_type loan_purpose  \
# 0        24890  2019         cf       3         nopre          0           p1
# 1        24891  2019         cf       2         nopre          1           p1
# 2        24892  2019         cf       2           pre          0           p1
# 3        24893  2019         cf       2         nopre          0           p4
# 4        24894  2019         cf       1           pre          0           p1
# ...        ...   ...        ...     ...           ...        ...          ...
# 148665  173555  2019         cf       3         nopre          0           p3
# 148666  173556  2019         cf       2         nopre          0           p1
# 148667  173557  2019         cf       2         nopre          0           p4
# 148668  173558  2019         cf       0         nopre          0           p4
# 148669  173559  2019         cf       0         nopre          0           p3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139520 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         139520 non-null  int64
#  1   year                       139520 non-null  int64
#  2   loan_limit                 136272 non-null  object
#  3   Gender                     139520 non-null  int32
#  4   approv_in_adv              138643 non-null  object
#  5   loan_type                  139520 non-null  int32
#  6   loan_purpose               139394 non-null  object
#  7   Credit_Worthiness          139520 non-null  int32
#  8   open_credit                139520 non-null  object
#  9   business_or_commercial     139520 non-null  int32
#  10  loan_amount                139520 non-null  int64
#  11  rate_of_interest           139520 non-null  float64
#  12  Interest_rate_spread       139520 non-null  float64
# ...

# %%
df['occupancy_type']=le.fit_transform(df['occupancy_type'])

# %%
df['age']=le.fit_transform(df['age'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139520 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         139520 non-null  int64
#  1   year                       139520 non-null  int64
#  2   loan_limit                 136272 non-null  object
#  3   Gender                     139520 non-null  int32
#  4   approv_in_adv              138643 non-null  object
#  5   loan_type                  139520 non-null  int32
#  6   loan_purpose               139394 non-null  object
#  7   Credit_Worthiness          139520 non-null  int32
#  8   open_credit                139520 non-null  object
#  9   business_or_commercial     139520 non-null  int32
#  10  loan_amount                139520 non-null  int64
#  11  rate_of_interest           139520 non-null  float64
#  12  Interest_rate_spread       139520 non-null  float64
# ...

# %%
df
# Out:
#             ID  year loan_limit  Gender approv_in_adv  loan_type loan_purpose  \
# 0        24890  2019         cf       3         nopre          0           p1
# 1        24891  2019         cf       2         nopre          1           p1
# 2        24892  2019         cf       2           pre          0           p1
# 3        24893  2019         cf       2         nopre          0           p4
# 4        24894  2019         cf       1           pre          0           p1
# ...        ...   ...        ...     ...           ...        ...          ...
# 148665  173555  2019         cf       3         nopre          0           p3
# 148666  173556  2019         cf       2         nopre          0           p1
# 148667  173557  2019         cf       2         nopre          0           p4
# 148668  173558  2019         cf       0         nopre          0           p4
# 148669  173559  2019         cf       0         nopre          0           p3
#
# ...

# %%
df.to_csv('new_dataset_disseration.csv')

# %%
df.shape
# Out:
# (139520, 34)

# %%
#cheking the imbalance in the dataset using the depepndent variable
df.Status.value_counts()
# Out:
# 0    104120
# 1     35400
# Name: Status, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'Secured_by', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'LTV', 'Region', 'Security_Type',
#        'Status', 'dtir1'],
#       dtype='object')

# %%
#heat map
plt.figure(figsize=(18,8))
sns.set_context('notebook',font_scale = 1.3)
sns.heatmap(df.corr(),annot=True,linewidth =2)
plt.tight_layout()
# Out:
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
print(df.columns)
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'Secured_by', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'LTV', 'Region', 'Security_Type',
#        'Status', 'dtir1'],
#       dtype='object')

# %%
X_data = ['Gender','loan_type','loan_amount','Interest_rate_spread',
          'property_value','Secured_by','income','Credit_Score','age',
          'LTV', 'dtir1']
df[X_data] = df[X_data].apply(pd.to_numeric, errors='coerce')
df[X_data] = df[X_data].astype(float)
X = df[X_data]
df['Status'] = pd.to_numeric(df['Status'], errors='coerce').astype(float)
y = df[['Status']]

#y= df['Status']
#X= df.drop(['Status'],axis=1)

# %%
status_counts = df['Status'].value_counts()
print(status_counts)
# Out:
# 0.0    104120
# 1.0     35400
# Name: Status, dtype: int64

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy import stats

# %%
#splitting the dataset into training and testing datasets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10, stratify= y)

print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (97664, 11) (97664, 1)
# Test set: (41856, 11) (41856, 1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139520 entries, 0 to 148669
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                139520 non-null  float64
#  1   loan_type             139520 non-null  float64
#  2   loan_amount           139520 non-null  float64
#  3   Interest_rate_spread  139520 non-null  float64
#  4   property_value        139520 non-null  float64
#  5   Secured_by            139520 non-null  float64
#  6   income                139520 non-null  float64
#  7   Credit_Score          139520 non-null  float64
#  8   age                   139520 non-null  float64
#  9   LTV                   139520 non-null  float64
#  10  dtir1                 139520 non-null  float64
# dtypes: float64(11)
# memory usage: 12.8 MB

# %%
#using KNN algorithm for training and prediction
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# Create an imputer
imputer = SimpleImputer(strategy='mean')

# Fit and transform the imputer on training data
X_train_imputed = imputer.fit_transform(X_train)

# Transform the imputer on test data
X_test_imputed = imputer.transform(X_test)

# Create and train the KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(X_train_imputed, y_train)

# Predict on the imputed test data
y_predict = model.predict(X_test_imputed)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
print(type(X_test))
print(X_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (41856, 11)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))
# Out:
# 0.8394734327217125

# %%
#pd.crosstab(y_test,y_predict)

# %%
pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
#applying smote to training dataset
smote=SMOTE()
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train.astype('float'),y_train)

# %%
X_train_smote, y_train_smote = smote.fit_resample(X_train.astype('float'),y_train)

# %%
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
from collections import Counter

# %%
Print the class distribution after applying SMOTE
print("Before SMOTE :" , Counter(y_train))
print("After SMOTE :" , Counter(y_train_smote))

# %%
model.fit(X_train_smote,y_train_smote)
y_predict = model.predict(X_test)
print(accuracy_score(y_test,y_predict))

# %%
#pd.crosstab(y_test,y_predict)

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#X_train_imputed

# %%
X
# Out:
#         Gender  loan_type  loan_amount  Interest_rate_spread  property_value  \
# 0          3.0        0.0     116500.0              0.441656   118000.000000
# 1          2.0        1.0     206500.0              0.441656   497893.465696
# 2          2.0        0.0     406500.0              0.200000   508000.000000
# 3          2.0        0.0     456500.0              0.681000   658000.000000
# 4          1.0        0.0     696500.0              0.304200   758000.000000
# ...        ...        ...          ...                   ...             ...
# 148665     3.0        0.0     436500.0              0.257100   608000.000000
# 148666     2.0        0.0     586500.0              0.854400   788000.000000
# 148667     2.0        0.0     446500.0              0.081600   728000.000000
# 148668     0.0        0.0     196500.0              0.582400   278000.000000
# 148669     0.0        0.0     406500.0              1.387100   558000.000000
#
# ...

# %%
dataset_path = 'new_dataset_disseration.csv'
df = pd.read_csv(dataset_path)

# Create a scatter plot with regression line
plt.figure(figsize=(8, 4))
sns.regplot(x='income', y='Status', data=df, scatter_kws={'s': 50}, line_kws={'color': 'red'})
plt.title('Regression Plot: Income vs. Loan Repayment Amount')
plt.xlabel('income')
plt.ylabel('Status')
plt.show()

# %%
# Assuming you have a dataset with 'Income' and 'LoanStatus' columns
# Replace 'your_dataset.csv' with the actual path or URL to your dataset
dataset_path = dataset_path = 'new_dataset_disseration.csv'
df = pd.read_csv(dataset_path)

# Define income bins
income_bins = [0, 2000, 4000, 6000, 8000, float('inf')]
income_labels = ['0-2k', '2k-4k', '4k-6k', '6k-8k', '8k+']

# Create a new column 'IncomeGroup' based on the bins
df['IncomeGroup'] = pd.cut(df['income'], bins=income_bins, labels=income_labels, right=False)

# Create a histogram for income based on loan repayment status
plt.figure(figsize=(10, 4))
sns.histplot(data=df, x='IncomeGroup', hue='Status', multiple='stack', bins=income_bins, palette='Set1')
plt.title('Histogram of Income by Loan Repayment Status')
plt.xlabel('Income Group')
plt.ylabel('Frequency')
plt.legend(title='Loan Status', labels=['Not Repaid', 'Fully Repaid'])
plt.show()

# %%
# Assuming you have a dataset with 'DebtToIncomeRatio' and 'LoanStatus' columns
# Replace 'your_dataset.csv' with the actual path or URL to your dataset
dataset_path = dataset_path = 'new_dataset_disseration.csv'
df = pd.read_csv(dataset_path)

# Define income bins
dtir1_bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, float('inf')]
dtir1_labels = ['0-5', '5-10', '10-15', '15-20', '20-25', '25-30', '30-35', '35-40', '40-45', '45-50','50+']

# Create a new column 'IncomeGroup' based on the bins
df['Debt-To-IncomeGroup'] = pd.cut(df['dtir1'], bins=dtir1_bins, labels=dtir1_labels, right=False)

# Create a histogram for debt-to-income ratio based on loan repayment status
plt.figure(figsize=(10, 4))
sns.histplot(data=df, x='Debt-To-IncomeGroup', hue='Status', multiple='stack', bins=dtir1_bins, palette='Set1')
plt.title('Histogram of Debt-To-Income by Loan Repayment Status')
plt.xlabel('Debt-To-Income Group')
plt.ylabel('Frequency')
plt.legend(title='Loan Status', labels=['Not Repaid', 'Fully Repaid'])
plt.show()

# %%
# Assuming you have a dataset with 'Gender' and 'LoanStatus' columns
# Replace 'your_dataset.csv' with the actual path or URL to your dataset
dataset_path = 'new_dataset_disseration.csv'
df = pd.read_csv(dataset_path)

# Define income bins
Gender_bins = [0, 1, 2, 3, float('inf')]
Gender_labels = ['Female', 'Joint', 'male', 'Sex Not Available']

# Create a new column 'IncomeGroup' based on the bins
df['Gender'] = pd.cut(df['Gender'], bins=Gender_bins, labels=Gender_labels, right=False)

# Create a histogram for debt-to-income ratio based on loan repayment status
plt.figure(figsize=(10, 4))
sns.histplot(data=df, x='Gender', hue='Status', multiple='stack', bins=Gender_bins, palette='Set1')
plt.title('Histogram of Gender by Loan Repayment Status')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.legend(title='Loan Status', labels=['Not Repaid', 'Fully Repaid'])
plt.show()

# %%
dataset_path = 'new_dataset_disseration.csv'
df = pd.read_csv(dataset_path)
gender_repayment_rates = df.groupby('Gender')['Status'].value_counts(normalize=True).unstack()
print(gender_repayment_rates)
# Out:
# Status         0         1
# Gender
# 0       0.745260  0.254740
# 1       0.799162  0.200838
# 2       0.729571  0.270429
# 3       0.707878  0.292122

# %%
#Plotting the graph for collateral value and repayment status
dataset_path = 'new_dataset_disseration.csv'
df = pd.read_csv(dataset_path)

# Define income bins
property_value_bins = [0, 200000, 400000, 600000, 800000, 1000000, 1200000, 1400000, 1600000, float('inf')]
property_value_labels = ['200k', '400k', '600k', '800k', '1000k', '1200k', '1400k', '1600k', '1600k+']

# Create a new column 'IncomeGroup' based on the bins
df['property_value'] = pd.cut(df['property_value'], bins=property_value_bins, labels=property_value_labels, right=False)

# Create a histogram for debt-to-income ratio based on loan repayment status
plt.figure(figsize=(10, 4))
sns.histplot(data=df, x='property_value', hue='Status', multiple='stack', bins=property_value_bins, palette='Set1')
plt.title('Histogram of property_value by Loan Repayment Status')
plt.xlabel('property_value')
plt.ylabel('Frequency')
plt.legend(title='Loan Status', labels=['Not Repaid', 'Fully Repaid'])
plt.show()

# %%
dataset_path = 'new_dataset_disseration.csv'
df = pd.read_csv(dataset_path)
plt.figure(figsize=(8, 4))
sns.boxplot(x='Status', y='LTV', data=df, palette='Set1')
plt.title('Loan Repayment by LTV Ratio')
plt.xlabel('Loan Status')
plt.ylabel('LTV Ratio')
plt.show()

# %%
#X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

#xgb=XGBClassifier(max_depth = 6, n_estiators=200)
#xgb.fit(X_train,y_train)

# %%
def gini(y_true, y_pred, sample = None):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    if sample:
        print(f'Gini on {sample} = {100*(2*auc(fpr,tpr)-1):.1f}')
    return 100*(2*auc(fpr,tpr)-1), fpr, tpr

def plot_gini(y_true_train, y_pred_train, y_true_test, y_pred_test):
    fig= plt.figure(figsize=(7,5))
    ax = fig.add_subplot(1,1,1)

    train_gini, fpr_train, tpr_train = gini(y_true_train, y_pred_train)
    test_gini, fpr_test, tpr_test = gini(y_true_test, y_pred_test)
    
    ax.plot(fpr_test, tpr_test, color='green', label='Test (GINI = %0.1f)' % (test_gini))
    ax.plot(fpr_train, tpr_train, color='red', label='Train (GINI = %0.1f)' % (train_gini))
    ax.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('ROC Curve', fontsize=16)
    ax.legend(loc="lower right", frameon=False)
    plt.show()  
    
def feat_imp(model, n = None):
    imp_type = ['weight', 'gain', 'cover', 'total_gain', 'total_cover']
    df_imp = pd.DataFrame(columns=['type', 'feature', 'importance'])

    for importance in imp_type:
        FI = pd.DataFrame.from_dict(model.get_booster().get_score(importance_type=importance), orient = 'index', columns=['importance']).reset_index().sort_values('importance', ascending = False)
        FI.columns = ['feature', 'importance']
        FI['importance'] = FI['importance']/sum(FI['importance'])
        FI.insert(0,'type',importance)
        df_imp = df_imp.append(FI)
    df_imp = df_imp.pivot(index='feature',columns='type', values='importance')
    df_imp['avg'] = df_imp[imp_type].mean(axis=1)
    if n:
        return df_imp.sort_values('gain', ascending=False).head(n)
    else:
        return df_imp.sort_values('gain', ascending=False)

# %%
xgb1=XGBClassifier(objective='binary:logistic', seed=42,n_estimators=200)
xgb1.fit(X_train,y_train,verbose=True, early_stopping_rounds=5, eval_metric='auc', eval_set=[(X_test,y_test)])
# Out:
# `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-auc:0.99837
# [1]	validation_0-auc:0.99837
# [2]	validation_0-auc:0.99920
# [3]	validation_0-auc:0.99943
# [4]	validation_0-auc:0.99943
# [5]	validation_0-auc:0.99948
# [6]	validation_0-auc:0.99948
# [7]	validation_0-auc:0.99949
# [8]	validation_0-auc:0.99950
# [9]	validation_0-auc:0.99950
# [10]	validation_0-auc:0.99950
# [11]	validation_0-auc:0.99950
# [12]	validation_0-auc:0.99951
# [13]	validation_0-auc:0.99950
# [14]	validation_0-auc:0.99950
# [15]	validation_0-auc:0.99951
# [16]	validation_0-auc:0.99951
# [17]	validation_0-auc:0.99951
# [18]	validation_0-auc:0.99952
# [19]	validation_0-auc:0.99952
# [20]	validation_0-auc:0.99952
# ...

# %%
from sklearn.feature_selection import RFE
estimator=xgb1
#Assuming estimator is your machine learning model
selector = RFE(estimator, n_features_to_select=11)  # Choose the desired number of features
selector.fit(X, y)

selected_features = X.columns[selector.support_]
print(selected_features)
# Out:
# Index(['Gender', 'loan_type', 'loan_amount', 'Interest_rate_spread',
#        'property_value', 'Secured_by', 'income', 'Credit_Score', 'age', 'LTV',
#        'dtir1'],
#       dtype='object')

# %%
# Training and test set accuracies
#selected_features
X = selected_features
xgb_test =xgb1.predict(X_test)
print(X)


#from sklearn import metrics 
#print("Accuracy of train set = ", metrics.accuracy_score(y_train, xgb1.predict(X_train)))
#print("Accuracy of test set = ", metrics.accuracy_score(y_test, xgb_test))
# Out:
# Index(['Gender', 'loan_type', 'loan_amount', 'Interest_rate_spread',
#        'property_value', 'Secured_by', 'income', 'Credit_Score', 'age', 'LTV',
#        'dtir1'],
#       dtype='object')

# %%
#plotting the roc curve 

train_gini, _, _ = gini(y_train, xgb1.predict_proba(X_train)[:,1], 'train')
test_gini,_ , _ = gini(y_test, xgb1.predict_proba(X_test)[:,1], 'test')

plot_gini(y_train, xgb1.predict_proba(X_train)[:,1], y_test, xgb1.predict_proba(X_test)[:,1])
# Out:
# Gini on train = 100.0
# Gini on test = 100.0

# %%
#feature importance
from xgboost import XGBClassifier
from xgboost import plot_importance
X=selected_features
# fit model to training data
xgb_model = XGBClassifier(random_state = 0 )
xgb_model.fit(X_train, y_train)

print("Feature Importances : ", xgb_model.feature_importances_)

# plot feature importance
plot_importance(xgb_model)
plt.show()
# Out:
# Feature Importances :  [8.0665009e-04 9.7577058e-04 6.9947937e-04 9.9297589e-01 9.6528779e-04
#  0.0000000e+00 7.4937684e-04 6.5853877e-04 5.2259682e-04 9.0446894e-04
#  7.4205763e-04]

# %%
plot_importance(xgb)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
feat_imp(xgb1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16060\2345951328.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_16060\2345951328.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_16060\2345951328.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_16060\2345951328.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\User\AppData\Local\Temp\ipykernel_16060\2345951328.py:32: FutureWarning:
#
# ...

# %%
df2 = df.where(df['rate_of_interest'] > 4)
df3 = df2.where(df2['Status'] ==1)


pd.crosstab(index=df3['Status'], columns=df3['rate_of_interest'])
# Out:
# rate_of_interest  4.045476
# Status
# 1.0                  35400

# %%
# !pip install shap
# !pip install explainerdashboard

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Create an XGBoost model
model = xgb.XGBClassifier(
    objective='binary:logistic',  # for binary classification tasks
    eval_metric='logloss',        # specify evaluation metric
    random_state=42               # for reproducibility
)

# %%
print(X)
# Out:
# Index(['loan_type', 'loan_amount', 'Interest_rate_spread', 'property_value',
#        'income', 'Credit_Score', 'LTV', 'dtir1'],
#       dtype='object')

# %%
# Train the model on the training set
model.fit(X_train, y_train)
# Make predictions on the testing set
y_pred = model.predict(X_test)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:233: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
# Evaluate the model performance
from sklearn.metrics import accuracy_score
classification_rep = classification_report(y_test, y_pred)

# %%
# Print the results
print(f"Accuracy: {accuracy:.4f}")
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 1.0000
#
# Confusion Matrix:
#  [[31236     0]
#  [    0 10620]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.96      0.90     31236
#          1.0       0.80      0.49      0.61     10620
#
#     accuracy                           0.84     41856
#    macro avg       0.82      0.73      0.75     41856
# weighted avg       0.83      0.84      0.83     41856

# %%
#BUILDING A MODEL USING LINEAR REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Create a Logistic Regression model
model = LogisticRegression(random_state=42)

# %%
# Train the model on the training set
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Make predictions on the testing set
y_pred = model.predict(X_test)

# %%
# Evaluate the model performance
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
# Evaluate the model performance
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
# Out:
# Accuracy: 0.7463
#
# Confusion Matrix:
#  [[31236     0]
#  [10620     0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.75      1.00      0.85     31236
#          1.0       0.00      0.00      0.00     10620
#
#     accuracy                           0.75     41856
#    macro avg       0.37      0.50      0.43     41856
# weighted avg       0.56      0.75      0.64     41856
